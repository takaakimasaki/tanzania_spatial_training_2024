# %% [markdown]
# <a href="https://githubtocolab.com/gee-community/geemap/blob/master/examples/notebooks/12_zonal_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %% [markdown]
# Load libraries

# %%
import ee
import geemap
import os
import getpass

ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Set the path

# %%
username = getpass.getuser()
if username == "WB495141":
    dir_output = 'OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
region = ee.Geometry.BBox(29.60168, -11.76347, 40.44495, -0.9857875)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
collection = (
    ee.ImageCollection(
    "projects/UNFAO/ASIS/ASI_A"
).filterBounds(region).filterDate('2022-01-01','2023-12-31').filter(ee.Filter.listContains("system:band_names", "ASI_A"))
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
out_dir = os.path.join(os.path.expanduser('~'), dir_output)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
map = geemap.Map()
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
print(collection.aggregate_array('system:index').getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).". Details: "ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(collection.aggregate_array('system:index').getInfo())
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Optional[Any]:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:1107, in computeValue(obj)
#    1104 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1105 _maybe_populate_workload_tag(body)
# -> 1107 return _execute_cloud_call(
#    1108     _get_cloud_projects()
#    1109     .value()
#    1110     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1111 )['result']
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:404, in _execute_cloud_call(call, num_retries)
#     402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
# --> 404   raise _translate_cloud_exception(e)
#
# EEException: ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).

# %%
geemap.ee_export_image_collection(collection, out_dir=out_dir, region = region)
# Out:
# Total number of images: 123
#
# Exporting 1/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-01_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2983baae942095954daaadcc9d3b528c-edbe354075e56d5f19a5c497b411303f:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-01_S1_C.tif
#
#
# Exporting 2/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-01_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c109aab3b8c6b9e23c0906602c5fdb8e-065653ef8ff50db3f9b394d5ce880c28:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-01_S1_P.tif
#
#
# Exporting 3/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-01_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4547a9520fb02fe57c5cca3facda01d3-dbf2f2c5312a791e118fb7957c626df5:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-01_S2_C.tif
#
#
# Exporting 4/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-01_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/244b592b739d8168d216693a7183fa79-5df624f32ce695dd61900f74424c5e65:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-01_S2_P.tif
#
#
# Exporting 5/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-02_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b8f5e61602f81c954b5fab26adc613cb-3343bd46125e1fc8fca2b724973bd4bd:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-02_S1_C.tif
#
#
# Exporting 6/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-02_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aadd308fa5e0b1441601afe9c1498f7b-f82b1ea0d21f0be85ef70998e63b96f2:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-02_S1_P.tif
#
#
# Exporting 7/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-02_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/65034002161c2db585fa63ddef739f70-d8a6bf93c9c9f7cd9997f74cc5de6125:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-02_S2_C.tif
#
#
# Exporting 8/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-02_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/77601ca7851f82812524cb893713a98c-f5f921eca4b992f7eade2d0a4fb0cf0f:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-02_S2_P.tif
#
#
# Exporting 9/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-03_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/24a3df2e8b2d53a7ed13a3302be2bad9-42b2a696e0d325e00491076ee2fca9a2:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-03_S1_C.tif
#
#
# Exporting 10/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-03_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8c1060503a6b782ef59a5fc6692b1cfd-9e186fd0b8d66cb13c9053895b106c73:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-03_S1_P.tif
#
#
# Exporting 11/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-03_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/209484ddaf8580b8ae044005e57db441-37248a65faec6193e8120e72ca5cb489:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-03_S2_C.tif
#
#
# Exporting 12/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-03_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/29d409ebd29363f22508d2909dbcbb99-ca671162ea5cf32711c00f098a25d402:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-03_S2_P.tif
#
#
# Exporting 13/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-04_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/60bb92aeaaaefc9f8d681cd1e78912f6-d3fc60cc2736d0b688a2f879c9be43fc:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-04_S1_C.tif
#
#
# Exporting 14/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-04_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12e8dcc714703ae5d29f9fe42083f362-1b4b841795b7dd196c7516bd19f45723:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-04_S1_P.tif
#
#
# Exporting 15/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-04_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9c5d43a12155b63a53703b8034b2ca75-2cf26aebb5f9499297f6868d817999e6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-04_S2_C.tif
#
#
# Exporting 16/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-04_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dfbd356933f294918210d715668a9e87-c6d18f842056ba99471b5c47dda8340b:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-04_S2_P.tif
#
#
# Exporting 17/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-05_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/69abeec1be77b9b811da6489f4bdbc9b-6cfbd0969aec004af2608680a0a8007e:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-05_S1_C.tif
#
#
# Exporting 18/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-05_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/74a96fc1326133154928a4ab26a84b52-bcf624a399bb6af753213629d4bb9bca:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-05_S1_P.tif
#
#
# Exporting 19/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-05_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/11329901898877f482cd597224f15c4f-a2303d2f8abfd3518daf1524d0f4a409:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-05_S2_C.tif
#
#
# Exporting 20/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-05_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9b5a01f229585758b175a4b03a339d65-ef75595673308f60297cb45a4680eec6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-05_S2_P.tif
#
#
# Exporting 21/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-06_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3f6f4a4024fd5e075efe74d314c27a50-59ddeb504534b08939beba31c5a9f1a3:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-06_S1_C.tif
#
#
# Exporting 22/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-06_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7d5943e77c9c622050580e88f8861ebd-a690179326326669c334d8c6ea6b2868:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-06_S1_P.tif
#
#
# Exporting 23/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-06_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d7a4ded384cf60df855beda3baccd415-3700d50d0c43ddb5d6eb737575beac40:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-06_S2_C.tif
#
#
# Exporting 24/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-06_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a7f60cd0eb780696aad558b9e60cdb03-f8d4b4379d6411776ea242e54a85da64:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-06_S2_P.tif
#
#
# Exporting 25/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-07_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/02914f053413afc2874ad353d3ef8bc3-329e256ff57479a07817243c4c285f7a:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-07_S1_C.tif
#
#
# Exporting 26/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-07_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/33a12a77df971f51673a6a54b9192e7e-0e8b9caace277543b6c63d992c1924da:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-07_S1_P.tif
#
#
# Exporting 27/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-07_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc33fbba28a532733cb5328685d7ef1d-690992477fc6ada4b9bc3c71519d58f7:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-07_S2_C.tif
#
#
# Exporting 28/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-07_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/859126f1265b5b2a6f8812e52bee6c62-d0f88c022796b8da7394f89780d6911d:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-07_S2_P.tif
#
#
# Exporting 29/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-08_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/50a7d3d6323437de771e9001a4d2cfe2-ff7d861bef3ec75a5a89558bdafe5d13:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-08_S1_C.tif
#
#
# Exporting 30/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-08_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/da59b7f9965f7ad35a675849a8355690-85d30b787b80ceba4422dbf6f2010a63:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-08_S1_P.tif
#
#
# Exporting 31/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-08_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eaa4624737809241c035a73a56df8866-dba97657196a427789bf41f7ec54c1f1:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-08_S2_C.tif
#
#
# Exporting 32/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-08_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6fdac8e630cb911cc6eb76d22362f89e-99dd0860e211cc551cd1c1b6b11a7a91:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-08_S2_P.tif
#
#
# Exporting 33/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-09_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/18cdba5bf1aec43719170bd5792187a6-666b71cc057db1e3f24bc130b0b4819e:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-09_S1_C.tif
#
#
# Exporting 34/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-09_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b572c23529e7ef74525f5a2da2d3c787-9870e8e325b44f0dcaad5238e5c7c190:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-09_S1_P.tif
#
#
# Exporting 35/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-09_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/40f615011bd52fc6f204ed1f1711b1fd-ac7b8e9a5dd2a951e0cdeb8a03117f3a:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-09_S2_C.tif
#
#
# Exporting 36/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-09_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/674cbdd52a2ca29992f50419dae0af1f-a627f9005812f234fefbf915dd0170f2:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-09_S2_P.tif
#
#
# Exporting 37/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-10_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/11df4e7a894583799bd2522ab2ec4a5e-74b8c8b55d4a9ed0b95e2976a29045f7:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-10_S1_C.tif
#
#
# Exporting 38/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-10_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9bdb372ef376400ec2d5a97408c01770-81975e5a1599287b7d19f3866fe35190:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-10_S1_P.tif
#
#
# Exporting 39/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-10_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ff97262e31e5cd893806e37606c973b6-0b8b8c835179ad92c756480e7262e4b4:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-10_S2_C.tif
#
#
# Exporting 40/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-10_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/095fa4081c007005182aaeec921db9f1-a792e8fa9736c0838343e3f16141b536:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-10_S2_P.tif
#
#
# Exporting 41/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-11_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/154c1790c1cfc90507db25192393ab11-6249637550fc14337c279b79686b6268:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-11_S1_C.tif
#
#
# Exporting 42/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-11_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c432d8507d815bf2271d2f52cf94f529-e12308ec9a2ccee89c3abab80ce43c72:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-11_S1_P.tif
#
#
# Exporting 43/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-11_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4fc881c16a73a067ba7c70f2b96833db-4b61f22c407e96c0c9cc05d6e491e5a7:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-11_S2_C.tif
#
#
# Exporting 44/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-11_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d4e530f6eaeb30aa9b193b16e6ff4223-2ba99826d97069bc3c12de52d17c24a4:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-11_S2_P.tif
#
#
# Exporting 45/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-12_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bb67a78ee7111bac499273f51f0401f9-3cec4b94b63a6dd0923218d9574541da:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-12_S1_C.tif
#
#
# Exporting 46/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-12_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/863f82e48079dee699a6b3c2ab16dcb6-1f6caa60e12301bca66f2fed113dc5f1:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-12_S1_P.tif
#
#
# Exporting 47/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-12_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2d6e496abde77417033f9460842ef5dd-c83882e5bae7fa6be095ef63b20c4959:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-12_S2_C.tif
#
#
# Exporting 48/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-12_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/798673faf82175d3f743252f1643fe82-a608721654343cc42d33afdddac84ae6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-12_S2_P.tif
#
#
# Exporting 49/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-13_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/50ee42324760b2b6d4c24ad6f5b66231-413b4db5a20ded9fcf7d9b75b074198d:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-13_S1_C.tif
#
#
# Exporting 50/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-13_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8ae42a70b589e369ce843d5c9c1f303d-1bd57072ef154e78c73354aae1aaaf2a:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-13_S1_P.tif
#
#
# Exporting 51/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-13_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/845ed3e29b8aea08e9dd722467ce78c0-5beca86e7e90fff192b29362fa6591b8:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-13_S2_C.tif
#
#
# Exporting 52/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-13_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/94bbe6af6a9edb133b697e061e947455-69496b277f000ea266c4f08b292671ea:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-13_S2_P.tif
#
#
# Exporting 53/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-14_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1e1eb5dac9e480e6ca44723b95a064a7-a307071f296ad53a2d4e93d106df0f8b:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-14_S1_C.tif
#
#
# Exporting 54/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-14_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fc0e02d0d2cc1f4fd263ddb1a302bf5e-3b1c54797c9ca0c85bde1f5328a8e529:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-14_S1_P.tif
#
#
# Exporting 55/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-14_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/83d1327f1c8fa87a79baac51f46b6b9d-e21cbeb5cb91b3b8170d3514ad812493:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-14_S2_C.tif
#
#
# Exporting 56/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-14_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1e5e114d27bf07e4cfa3582f8b7c18af-c0a1cb0801d4e9c1631a1f526ccd1f03:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-14_S2_P.tif
#
#
# Exporting 57/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-15_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bced00b6aab6f58c889b559fdf5d3b6c-c31368a0bfa6d56ca79eafac4363f1bd:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-15_S1_C.tif
#
#
# Exporting 58/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-15_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d52dfe14452610f68be404f83b3b882c-da80a3c74c64de247707652d7bbbb81f:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-15_S1_P.tif
#
#
# Exporting 59/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-15_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dc80c167ba04a1bc87ab819f4716d587-343b7b984f62b8c0cce6eb76b36e57d7:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-15_S2_C.tif
#
#
# Exporting 60/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-15_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/94d976e6bf42ebcab2b67d7b85b7ed69-646739bcc14132ea923bc4619b2e95e0:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-15_S2_P.tif
#
#
# Exporting 61/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-16_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/604f335eec9f96510aa15bed77961a73-a9a8ebb20f5f5d00028e605d7a8a4586:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-16_S1_C.tif
#
#
# Exporting 62/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-16_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3974461e669f3a65a4585c7fd614347c-9c514d3cb8a898f93a6a6068f561e551:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-16_S1_P.tif
#
#
# Exporting 63/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-16_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ee9caf8d3bba5c1a40c68c7195f3cc9c-a738cd0d93e9ef79b341b7b59096e189:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-16_S2_C.tif
#
#
# Exporting 64/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-16_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/20c7a4d4030c44714e3a27f863ac7241-c4c6969af902a901f71a1f69856af5dc:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-16_S2_P.tif
#
#
# Exporting 65/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-17_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aa93f810060339d1aa869c33dc186bd1-16514c24319f7f4f0e33accedbef1829:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-17_S1_C.tif
#
#
# Exporting 66/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-17_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8fbb9b52d4bad84008d00c20126d3ae9-63b0dfbc41f33f0094f8636fb2d91913:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-17_S1_P.tif
#
#
# Exporting 67/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-17_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c0f5d47f6e2154a5831e18c5948b22da-d74dac61b0158b1cb8e20044d0fcbdf2:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-17_S2_C.tif
#
#
# Exporting 68/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-17_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/039a4d63e14f57ff3b314453c02f2688-9ae84a5e871dc5cbe321214980dac4a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-17_S2_P.tif
#
#
# Exporting 69/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-19_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/115b731fc3615d369829855d0500bb5a-eb769430245c50d0585eb9a65e220e0c:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-19_S1_C.tif
#
#
# Exporting 70/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-19_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7a11aaa0c09fce08d9c036aba6e60242-e83bf1121cc24dbb44b64c0bb580c5d0:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-19_S1_P.tif
#
#
# Exporting 71/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-19_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/466671bc5bca46a897c2f5a891cbd29a-e825259982ff75222079a9421b615767:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-19_S2_C.tif
#
#
# Exporting 72/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-19_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/712fe02830a232714f0c956844ca3ee5-79b4d2b15b10c5be35a6f0ad96997121:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-19_S2_P.tif
#
#
# Exporting 73/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-20_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ce1fc87ac648ee3cf417023b888be814-a9bd2735bdbaa08b16a553bde81ebb34:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-20_S1_C.tif
#
#
# Exporting 74/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-20_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b228388ff13a4485d62d0e796e201162-657dcaaf8016066df0d9f793792ffd6e:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-20_S1_P.tif
#
#
# Exporting 75/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-20_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e2843c60c6dcde3b76ce73771c886543-8f507c61a388a13b0b366c453e03ded8:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-20_S2_C.tif
#
#
# Exporting 76/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-20_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f7de57a1992954bcc46ce56f2fdaa0b-fc1ca464a5c9158c7562ba2c66438efc:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-20_S2_P.tif
#
#
# Exporting 77/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-21_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d2ca9556115cf94cf76ba6db3a38b88c-c12ae2c650fbb8dd9c75d87707d82fd6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-21_S1_C.tif
#
#
# Exporting 78/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-21_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/346b02d822acda76249f6464eab2ff9d-9094bda0e53bf473c2c649556fad1d34:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-21_S1_P.tif
#
#
# Exporting 79/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-21_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c543a94d66af84b1dedb24e6c69fa73c-58938b14317937199fc30080f7c7e8d9:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-21_S2_C.tif
#
#
# Exporting 80/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-21_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9ba16a83c23cf6109604bde359ea80d4-8480bd7d00c468fbcc5c8d348c06035a:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-21_S2_P.tif
#
#
# Exporting 81/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-22_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b0357d51666075f3966fb66029301398-bbf959c6c4e3810729086874ba8ed0e0:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-22_S1_C.tif
#
#
# Exporting 82/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-22_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cdd798b709c25a4413213760e69e43c2-f0c38e8fb7249ea757504d3e0599fa38:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-22_S1_P.tif
#
#
# Exporting 83/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-22_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0a13a69c1836119b62b1670161870558-58d682a5ea25d93b600f66ae1b740640:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-22_S2_C.tif
#
#
# Exporting 84/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-22_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e8c57060604400dee860eaef6a72fe54-ee229c3ecce9abacc7af87849622b690:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-22_S2_P.tif
#
#
# Exporting 85/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-23_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0fc518548c392eea1e9f5f4227eb7aa4-f54b3ed0a41737233aa597e4ee4c14f0:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-23_S1_C.tif
#
#
# Exporting 86/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-23_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/19adf0d69d62b025e95c74c3dcc5efd0-f1c92c3bb2dd8622718ea9d94d54ccf3:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-23_S1_P.tif
#
#
# Exporting 87/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-23_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/975eb526864add99148c62e4f1339ca4-4491f9b2810534fd3c138ed6e799f15d:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-23_S2_C.tif
#
#
# Exporting 88/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-23_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/25fcf4b8ade276ac0e48965309084efc-4861fd2beef68f3aa2504db6dc2aae91:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-23_S2_P.tif
#
#
# Exporting 89/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-24_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d70271802181f1ebc11fd45c2cd9101c-c2aca642a85213254d525239ee382860:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-24_S1_C.tif
#
#
# Exporting 90/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-24_S1_P.tif
# Generating URL ...
# ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8aaf3c534a782b24204b34734c69e1ed-255262b681744de0cf991eb30713df42:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-25_S1_P.tif
#
#
# Exporting 95/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-25_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fdb21cf73999f8ab90520058cef3b94d-4357a823753e7d80ee23a5218b2de61e:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-25_S2_C.tif
#
#
# Exporting 96/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-25_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b826ec0ceeed8150a449761dbdf734a7-fa09288e48ac42e482b7ebf54ac4e169:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-25_S2_P.tif
#
#
# Exporting 97/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-26_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/26fd51ccc0a26fae3185fbad24c84731-240426d383cd5e9fd83b7997fc4f2475:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-26_S1_C.tif
#
#
# Exporting 98/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-26_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1302df8f528583d8fc12740cf2342ec0-f616559b1fb0cd08f1a2e1b35812b428:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-26_S1_P.tif
#
#
# Exporting 99/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-26_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dffa8f1b4c76b94dc8b1b925586e8997-2e54ec5e034220b051486066459c8039:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-26_S2_C.tif
#
#
# Exporting 100/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-26_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/52d1f16eac7feefea8b26e2f605e7319-22e876439235a3a64d9d166f712e5664:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-26_S2_P.tif
#
#
# Exporting 101/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-27_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/97279800abe575133746276f5416b809-9fc3bc77aea46f84083df8263cc0d784:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-27_S1_C.tif
#
#
# Exporting 102/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-27_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a63da23ae240f79b71a44be9df9c596d-63f8f8a2725572b1b54f96f72344e2d1:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-27_S1_P.tif
#
#
# Exporting 103/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-27_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f6026fbda80e87d6589e9017c5e144a1-c03305887448984f014b49aac7e036b7:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-27_S2_C.tif
#
#
# Exporting 104/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-27_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6ec575325e253201e8179817955d0f54-a3c55e8dcad48cbff2b901ea36a43972:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-27_S2_P.tif
#
#
# Exporting 105/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-28_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc3f7565f4fefa932cbcd9e672010e7a-1885f8026068e6d21fe8b0d941ab73ff:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-28_S1_C.tif
#
#
# Exporting 106/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-28_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/954b51ba9c6e6ae28fd5e3b0be8f453f-20018cc73724e0058c392f45d067a099:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-28_S1_P.tif
#
#
# Exporting 107/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-28_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9d9a65eb888446a8b60f36fc1f63ea7a-3814ccac4efc7c201dc89e55bd192689:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-28_S2_C.tif
#
#
# Exporting 108/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-28_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/016ef63bc20e7507a80de774bd933d08-e23165e77ab1d3a418117216a012add2:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-28_S2_P.tif
#
#
# Exporting 109/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-29_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9b1d103bad5efc0fb7c30e1bca090054-15caad7e3ce4683eabbd8872d28e91d5:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-29_S1_C.tif
#
#
# Exporting 110/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-29_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/733c2f761643ad7d8a9cbdc79b26cac7-7d39a602069b5f5ebca726b91f63a38e:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-29_S2_C.tif
#
#
# Exporting 111/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-29_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/246a1a646b513f57e1e940bbcd4b7e34-84e96211cb3c1fcd02bb73f32b2d2c34:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-29_S2_P.tif
#
#
# Exporting 112/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-30_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/202d1aa751b8b13deec1a8c976b6e23d-07e2a89c04ee8ca66bce928d94c6d58c:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-30_S1_C.tif
#
#
# Exporting 113/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-30_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/24be23aa780046bdb29db89018f81af0-de37a7f734a091efd55439776f8313c0:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-30_S2_C.tif
#
#
# Exporting 114/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-30_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/48224a8b0ef0a6d2b031211a16669694-e44d67a0ced190d1ad32d5e85c9da4b6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-30_S2_P.tif
#
#
# Exporting 115/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-31_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/df33557cd76f92026dc1c8ff32ba2061-2d3c7ac534594316f43aa953bdfc85fa:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-31_S1_C.tif
#
#
# Exporting 116/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-31_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7b72bdaa3c58ab83ee3fa17c1803b276-330dbc5cba395e37128f7cd220946835:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-31_S1_P.tif
#
#
# Exporting 117/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-32_S2_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/29d28e1605dbad44a897411149aade45-184ccbe5f8207b23f89ec451fdbc7896:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-32_S2_C.tif
#
#
# Exporting 118/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-33_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0b6ce05ff0d72624e3f25d083374a533-b889b86b9b0863544a36bbe69776c84c:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-33_S1_C.tif
#
#
# Exporting 119/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-33_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6b51081f10048fcb291fd6922d55b48c-4833b9d6f8805af130588994ae0b43ff:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-33_S2_P.tif
#
#
# Exporting 120/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-34_S1_C.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f86b648ea0843a019f46a90ea895d7e-fb63ac24cc5244671a59cdbf98c5bf3b:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-34_S1_C.tif
#
#
# Exporting 121/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-34_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e332cf04742b6b48898c9b5c536ae811-39f0384e3a98f4696b4db4e80ea381be:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-34_S2_P.tif
#
#
# Exporting 122/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-35_S2_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0e0b2ca92c95e11d06bcaff642d23dc6-fc66afb54ad2b4e06a9da0d75b1abb3f:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-35_S2_P.tif
#
#
# Exporting 123/123: C:\Users\WB495141\OneDrive - WBG/poverty/tanzania_pti/doc/fy24/training_2024_04/climate-data-raw/tanzania/drought/asi\ASI_D_2023-36_S1_P.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ec2219446051251819cef808d8da9645-e182ca7d78a8e0d15fd878f2a80c72b6:getPixels
# Please wait ...
# Data downloaded to C:\Users\WB495141\OneDrive - WBG\poverty\tanzania_pti\doc\fy24\training_2024_04\climate-data-raw\tanzania\drought\asi\ASI_D_2023-36_S1_P.tif

# %%
collection = (
    ee.ImageCollection(
    "projects/UNFAO/ASIS/ASI_A"
).filterBounds(region).filterDate('2023-01-01','2023-12-31').filter(ee.Filter.listContains("system:band_names", "ASI_A"))
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
print(collection.aggregate_array('system:index').getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).". Details: "ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(collection.aggregate_array('system:index').getInfo())
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Optional[Any]:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:1107, in computeValue(obj)
#    1104 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1105 _maybe_populate_workload_tag(body)
# -> 1107 return _execute_cloud_call(
#    1108     _get_cloud_projects()
#    1109     .value()
#    1110     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1111 )['result']
#
# File C:\WBG\Anaconda3\envs\gee\Lib\site-packages\ee\data.py:404, in _execute_cloud_call(call, num_retries)
#     402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
# --> 404   raise _translate_cloud_exception(e)
#
# EEException: ImageCollection.load: ImageCollection asset 'projects/UNFAO/ASIS/ASI_A' not found (does not exist or caller does not have access).

# %%
geemap.ee_export_image_collection(collection, out_dir=out_dir, region = region)
# Out:
# Total number of images: 0
